# %% [markdown]
# # Breast Cancer Prediction
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from IPython.display import display
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ## Data Preparation

# %%
cancer = load_breast_cancer()
xTrain, xTest, yTrain, yTest = train_test_split(cancer.data, cancer.target, stratify=cancer.target, random_state=66)

# %% [markdown]
# ## Model Training

# %%
accuracy = []

# try nNeighbors from 1 to 10
neighborsSettings = range(1, 11)

for nNeighbors in neighborsSettings:
    # build the model
    clf = KNeighborsClassifier(n_neighbors=nNeighbors)
    clf.fit(xTrain, yTrain)
    
    # record accuracy
    accuracy.append([nNeighbors, clf.score(xTrain, yTrain), clf.score(xTest, yTest)])

# %% [markdown]
# ## Evaluation

# %%
training_accuracy = []
test_accuracy = []

accuracy_dataframe = pd.DataFrame(accuracy, columns=['Neighbors', 'Training Accuracy', 'Test Accuracy'])
pd.options.display.float_format = '{:,.2f}'.format
display (iris_dataframe)

for i in range(len(accuracy)):
    training_accuracy.append(accuracy[i][1])
    test_accuracy.append(accuracy[i][2])
    
plt.plot(neighborsSettings, training_accuracy, label="training accuracy")
plt.plot(neighborsSettings, test_accuracy, label="test accuracy")
plt.ylabel("Accuracy")
plt.xlabel("n_neighbors")
plt.legend()
# Out:
#    Neighbors  Training Accuracy  Test Accuracy
# 0          1               1.00           0.90
# 1          2               0.98           0.89
# 2          3               0.96           0.92
# 3          4               0.96           0.92
# 4          5               0.95           0.92
# 5          6               0.95           0.94
# 6          7               0.94           0.93
# 7          8               0.94           0.93
# 8          9               0.93           0.92
# 9         10               0.94           0.92

# %% [markdown]
# ## Visualisation

# %%
print("Sample counts per class:\n",
      {n: v for n, v in zip(cancer.target_names, np.bincount(cancer.target))})

bc_dataframe = pd.DataFrame(xTrain, columns=cancer.feature_names)
display(bc_dataframe)
# Out:
# Sample counts per class:
#  {'malignant': 212, 'benign': 357}
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          13.87         20.70           89.77     584.80             0.10
# 1          17.57         15.05          115.00     955.10             0.10
# 2          13.30         21.57           85.24     546.10             0.09
# 3          10.48         19.86           66.72     337.70             0.11
# 4          11.94         20.76           77.87     441.00             0.09
# ..           ...           ...             ...        ...              ...
# 421        12.45         16.41           82.85     476.70             0.10
# 422         9.00         14.40           56.36     246.30             0.07
# 423        14.58         21.53           97.41     644.80             0.11
# 424        13.65         13.16           87.88     568.90             0.10
# 425        20.73         31.12          135.70   1,419.00             0.09
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0                0.10            0.04                 0.02           0.16
# 1                0.12            0.10                 0.08           0.17
# 2                0.06            0.03                 0.02           0.18
# 3                0.06            0.05                 0.03           0.17
# 4                0.10            0.07                 0.04           0.16
# ..                ...             ...                  ...            ...
# 421              0.15            0.15                 0.05           0.21
# 422              0.03            0.00                 0.00           0.18
# 423              0.19            0.14                 0.09           0.23
# 424              0.09            0.04                 0.03           0.14
# 425              0.11            0.14                 0.09           0.18
#
#      mean fractal dimension  ...  worst radius  worst texture  \
# 0                      0.07  ...         15.05          24.75
# 1                      0.06  ...         20.01          19.52
# 2                      0.06  ...         14.20          29.20
# 3                      0.06  ...         11.48          29.46
# 4                      0.07  ...         13.24          27.29
# ..                      ...  ...           ...            ...
# 421                    0.07  ...         13.78          21.03
# 422                    0.07  ...          9.70          20.07
# 423                    0.07  ...         17.62          33.21
# 424                    0.06  ...         15.34          16.35
# 425                    0.06  ...         32.49          47.16
#
#      worst perimeter  worst area  worst smoothness  worst compactness  \
# 0              99.17      688.60              0.13               0.20
# 1             134.90    1,227.00              0.13               0.28
# 2              92.94      621.20              0.11               0.17
# 3              73.68      402.80              0.15               0.10
# 4              92.20      546.10              0.11               0.28
# ..               ...         ...               ...                ...
# 421            97.82      580.60              0.12               0.41
# 422            60.90      285.50              0.10               0.05
# 423           122.40      896.90              0.15               0.66
# 424            99.71      706.20              0.13               0.25
# 425           214.00    3,432.00              0.14               0.26
#
#      worst concavity  worst concave points  worst symmetry  \
# 0               0.14                  0.07            0.22
# 1               0.25                  0.15            0.28
# 2               0.12                  0.06            0.26
# 3               0.12                  0.07            0.29
# 4               0.24                  0.12            0.25
# ..               ...                   ...             ...
# 421             0.49                  0.13            0.32
# 422             0.01                  0.01            0.30
# 423             0.55                  0.27            0.43
# 424             0.18                  0.08            0.24
# 425             0.34                  0.17            0.29
#
#      worst fractal dimension
# 0                       0.08
# 1                       0.08
# 2                       0.07
# 3                       0.08
# 4                       0.10
# ..                       ...
# 421                     0.10
# 422                     0.08
# 423                     0.13
# 424                     0.09
# 425                     0.08
#
# [426 rows x 30 columns]
